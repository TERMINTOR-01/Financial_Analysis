# %% [markdown]
# # Frameworks

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Load Dataset

# %%
##Load Data
df=pd.read_csv("amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# # Dataset Overview

# %%
print("Data Shape",df.shape)
print("Size of data",df.size)
# Out:
# Data Shape (1465, 16)
# Size of data 23440

# %%
print(df.columns)
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# # Data Cleanning

# %% [markdown]
# ## Drop Un-Wanted Columns

# %%
df.drop(
    columns=[
        "img_link",
        "product_link",
        "review_content",
        "review_title",
        "review_id",
        "user_name",
        "user_id",
        "about_product"
    ],inplace=True
)

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# dtype: int64

# %%
df[df["rating_count"].isnull()]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count
# 282         ₹999                 80%    3.0          NaN
# 324         ₹999                 75%    5.0          NaN

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1463, 8)

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# dtype: int64

# %% [markdown]
# ## Fix data types

# %% [markdown]
# ##### Datatype change Required
#
# 1.discounted_price->float
#
# 2.actual_price->float
#
# 3.discount_percentage->int
#
# 4.rating->float
# 5.rating_count->int

# %%
# Price
price_columns = ["discounted_price", "actual_price"]

df[price_columns] = (
    df[price_columns]
    .replace({"₹": "", ",": ""}, regex=True)
    .astype(float)
)

print(df)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df.discount_percentage = (
    df.discount_percentage
    .replace({"%": "", ",": ""}, regex=True)
    .astype(float)
)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# %%
df.rating_count = (
    df.rating_count
    .replace({"%": "", ",": ""}, regex=True)
    .astype(float)
)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ## string parsing/splitting

# %%
## Category fix
df["category"] = df["category"].str.split("|").str[0]
# Out:
# C:\Users\Sahil Khan\AppData\Local\Temp\ipykernel_22980\454582929.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                    category  discounted_price  actual_price  \
# 0     Computers&Accessories             399.0        1099.0
# ...

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Feature engineering

# %%
df["Revenue_Potential"]=df["discounted_price"]*df["rating_count"]
# Out:
# C:\Users\Sahil Khan\AppData\Local\Temp\ipykernel_22980\1563695500.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                    category  discounted_price  actual_price  \
# 0     Computers&Accessories             399.0        1099.0
# ...

# %%
df['absolute_discounted_amount']=df['actual_price']-df['discounted_price']
# Out:
# C:\Users\Sahil Khan\AppData\Local\Temp\ipykernel_22980\1819317483.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                    category  discounted_price  actual_price  \
# 0     Computers&Accessories             399.0        1099.0
# ...

# %% [markdown]
# # Analysis

# %% [markdown]
# #### CO-Realtion

# %%
num_cols = [
    "discounted_price",
    "actual_price",
    "discount_percentage",
    "rating",
    "rating_count",
    "Revenue_Potential",
    "absolute_discounted_amount"
]

# %%
import plotly.express as px

fig = px.scatter_matrix(
    df,
    dimensions=num_cols,
    title="Scatter Matrix of Numerical Features"
)

fig.update_layout(
    width=1500,    # Width in pixels
    height=1500    # Height in pixels
)

fig.show()

# %%
corr = df[num_cols].corr()

corr
# Out:
#                             discounted_price  actual_price  \
# discounted_price                    1.000000      0.961910
# actual_price                        0.961910      1.000000
# discount_percentage                -0.242298     -0.117855
# rating                              0.121132      0.122467
# rating_count                       -0.027304     -0.036215
# Revenue_Potential                   0.468167      0.413662
# absolute_discounted_amount          0.763650      0.911056
#
#                             discount_percentage    rating  rating_count  \
# discounted_price                      -0.242298  0.121132     -0.027304
# actual_price                          -0.117855  0.122467     -0.036215
# discount_percentage                    1.000000 -0.155679      0.011294
# rating                                -0.155679  1.000000      0.102235
# rating_count                           0.011294  0.102235      1.000000
# ...

# %%
# Finding
#.If actual price is more then there is more discounted price
#.Higher The actual price higher the discounted amount
#.The priduct which are in higher disount people buy them more

# %% [markdown]
# #### 1. Pricing Efficiency & Discount Strategy

# %% [markdown]
# ###### 1.Are high discounts actually driving meaningful volume?

# %%
import plotly.express as px

fig = px.scatter(
    df,
    x="discount_percentage",
    y="rating_count",
    trendline="ols",
    title="Rating Count vs Discounted Price"
)

fig.show()

# %% [markdown]
# #### I suggests that higher discounts are not associated with proportionally higher customer engagement (using rating count as a proxy for demand). Therefore, discounting alone does not appear to be an effective strategy for increasing demand.

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                 category  discounted_price  actual_price  discount_percentage  \
# 0  Computers&Accessories             399.0        1099.0                 64.0
# 1  Computers&Accessories             199.0         349.0                 43.0
# 2  Computers&Accessories             199.0        1899.0                 90.0
# 3  Computers&Accessories             329.0         699.0                 53.0
# 4  Computers&Accessories             154.0         399.0                 61.0
#
#    rating  rating_count  Revenue_Potential  absolute_discounted_amount
# ...

# %% [markdown]
# #### 2.Deep vs. Shallow Discount Performance:

# %%
df["discount_tier"] = pd.cut(
    df["discount_percentage"],
    bins=[0, 10, 30, 50, 100],
    labels=["0-10%", "10-30%", "30-50%", "50%+"],
    include_lowest=True
)

df["discount_tier"].value_counts()
# Out:
# C:\Users\Sahil Khan\AppData\Local\Temp\ipykernel_22980\3439198061.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# discount_tier
# 50%+      693
# 30-50%    426
# 10-30%    259
# 0-10%      84
# Name: count, dtype: int64

# %%
tier_analysis = (
    df.groupby("discount_tier", observed=False)
      .agg(
          Avg_Rating_Count=("rating_count", "mean"),
          Avg_Revenue=("Revenue_Potential", "mean"),
          Avg_Discount=("discount_percentage", "mean"),
          Product_Count=("product_name", "count")
      )
      .reset_index()
)

# Convert to Thousands (K)
tier_analysis["Avg_Revenue"] = (tier_analysis["Avg_Revenue"] / 1000).round(2)

tier_analysis
# Out:
#   discount_tier  Avg_Rating_Count  Avg_Revenue  Avg_Discount  Product_Count
# 0         0-10%      12086.261905     55580.45      2.809524             84
# 1        10-30%      21457.169884    132503.10     22.166023            259
# 2        30-50%      16648.633803     51312.87     41.934272            426
# 3          50%+      18903.916306     15975.98     66.170274            693

# %%
comparison = tier_analysis.melt(
    id_vars="discount_tier",
    value_vars=["Avg_Rating_Count", "Avg_Revenue"],
    var_name="Metric",
    value_name="Value"
)

fig = px.bar(
    comparison,
    x="discount_tier",
    y="Value",
    color="Metric",
    barmode="group",
    title="Discount Tier Performance"
)

fig.update_layout(template="plotly_white")

fig.show()

# %% [markdown]
# ##### 1.0–10% Discount Tier
# ###### Very low discounts generate reasonable revenue, but customer engagement remains lower than products receiving moderate discounts.
#
# ##### 2.10–30% Discount Tier ⭐ (Best Performing)
# ###### Products with moderate discounts (10–30%) achieve the best balance between customer demand and revenue generation. This appears to be the most effective pricing strategy.
#
# ##### 3.30–50% Discount Tier
# ###### Increasing discounts beyond 30% does not improve customer engagement and is associated with lower revenue potential.
#
# ##### 4.50%+ Discount Tier
# ###### Deep discounts (50%+) do not generate proportionally higher customer engagement and are associated with the lowest revenue potential, suggesting that excessive discounting may be reducing profitability.

# %% [markdown]
# # Why is 10–30% Better than 50%?
#
# ## Suppose
# Product A
#
# Original Price = £100
#
# Discount = 20%
#
# Selling Price = £80
#
# Rating Count = 2000
#
# Revenue Potential:
# 80 × 2000
# =160000
#
# Product B
#
# Original Price = £100
#
# Discount = 60%
#
# Selling Price = £40
#
# Rating Count = 2300
#
# Revenue Potential:
# 40 ×2300
# =92000
#
# See Customers Only increase
# 2000 -> 23000
# But Price Decreasee
# 80 -> 40 (Revenue almost half.) leads to (Over Discounting.)

# %% [markdown]
# ## Product Distribution
#
# Interesting Things.
#
# Tier Products
#
# 1.0–10%	84
#
# 2.10–30%	259
#
# 3.30–50%	426
#
# 4.50%+	693
#
# Almost Half Dataset Covers in 50% Discount Means Company Gives Discount Aggressively But The Product Above 50% Gives Least Reveneue so we need to improve Pricing strategy

# %% [markdown]
# # 2. Profitability & Revenue Realization

# %% [markdown]
# #### Discount  Leakage

# %% [markdown]
# ##### Step 1: Total Discount Leakage

# %%
df["Total_Discount_Leakage"] = (
    df["absolute_discounted_amount"] * df["rating_count"]
)
# Out:
# C:\Users\Sahil Khan\AppData\Local\Temp\ipykernel_22980\1183686616.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ##### Step 2:Discount Leakage by Categorye

# %%
category_discount = (
    df.groupby("category")["Total_Discount_Leakage"]
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

# Convert to Lakhs
category_discount["Total_Discount_Leakage_Lakh"] = (
    category_discount["Total_Discount_Leakage"] / 100000
).round(2)

category_discount
# Out:
#                 category  Total_Discount_Leakage  Total_Discount_Leakage_Lakh
# 0            Electronics            3.884105e+10                    388410.53
# 1  Computers&Accessories            6.260240e+09                     62602.40
# 2           Home&Kitchen            4.194989e+09                     41949.89
# 3     MusicalInstruments            8.665899e+07                       866.59
# 4         OfficeProducts            1.499209e+07                       149.92
# 5    Health&PersonalCare            3.666663e+06                        36.67
# 6        HomeImprovement            3.576244e+06                        35.76
# 7          Car&Motorbike            1.856998e+06                        18.57
# 8             Toys&Games            0.000000e+00                         0.00

# %%
fig = px.bar(
    category_discount,
    x="category",
    y="Total_Discount_Leakage",
    title="Total Discount Leakage by Category",
    color="Total_Discount_Leakage",
    text_auto=".2s"
)

fig.update_layout(
    template="plotly_white",
    xaxis_title="Category",
    yaxis_title="Total Discount Amount (£)"
)

fig.show()

# %% [markdown]
# ##### Step 3: Top 10 Products with Highest Discount Leakage

# %%
top_discount = (
    df.sort_values("Total_Discount_Leakage", ascending=False)
      .head(10)
)

top_discount
# Out:
#      product_id                                       product_name  \
# 568  B08VB57558  Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM,...
# 935  B08GTYFC37  SanDisk 1TB Extreme Portable SSD 1050MB/s R, 1...
# 370  B09GFPVD9Y  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...
# 72   B09RFC46VP  Redmi 108 cm (43 inches) 4K Ultra HD Android S...
# 371  B09GFLXVH9  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...
# 566  B09GFPN6TP  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...
# 124  B08Y55LPBF  Redmi 126 cm (50 inches) 4K Ultra HD Android S...
# 64   B09F9YQQ7B  Redmi 80 cm (32 inches) Android 11 Series HD R...
# 953  B09F9YQQ7B  Redmi 80 cm (32 inches) Android 11 Series HD R...
# 332  B09RWQ7YR6  MI 138.8 cm (55 inches) 5X Series 4K Ultra HD ...
#
#                   category  discounted_price  actual_price  \
# 568            Electronics           37990.0       74999.0
# 935  Computers&Accessories           10389.0       32000.0
# ...

# %% [markdown]
# ##### Step 4: Compare Discount vs Revenue

# %%
comparison = top_discount.melt(
    id_vars="product_name",
    value_vars=["Total_Discount_Leakage", "Revenue_Potential"],
    var_name="Metric",
    value_name="Value"
)

fig = px.bar(
    comparison,
    x="product_name",
    y="Value",
    color="Metric",
    barmode="group",
    title="Top 10 Products: Discount Leakage vs Revenue Potential",
    text_auto=".2s"
)

fig.update_layout(
    template="plotly_white",
    xaxis_title="Product",
    yaxis_title="Amount (£)"
)

fig.update_xaxes(tickangle=45)

fig.show()

# %% [markdown]
# ##### Step 5: Discount Efficiency Ratio

# %%
df["Discount_Efficiency"] = (
    df["Revenue_Potential"] /
    df["Total_Discount_Leakage"]
).round(2)
# Out:
# C:\Users\Sahil Khan\AppData\Local\Temp\ipykernel_22980\924716093.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
lowest_efficiency = (
    df.sort_values("Discount_Efficiency")
      .loc[:, [
          "product_name",
          "category",
          "absolute_discounted_amount",
          "Revenue_Potential",
          "Discount_Efficiency"
      ]]
      .head(10)
)

lowest_efficiency
# Out:
#                                           product_name               category  \
# 695  rts [2 Pack] Mini USB C Type C Adapter Plug, T...  Computers&Accessories
# 372  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            Electronics
# 364  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            Electronics
# 368  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            Electronics
# 380  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            Electronics
# 334  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            Electronics
# 644  Sounce Spiral Charger Cable Protector Data Cab...  Computers&Accessories
# 407  Sounce Spiral Charger Cable Protector Data Cab...  Computers&Accessories
# 920  Silicone Rubber Earbuds Tips, Eartips, Earpads...            Electronics
# 602  LAPSTER Spiral Charger Spiral Charger Cable Pr...  Computers&Accessories
#
#      absolute_discounted_amount  Revenue_Potential  Discount_Efficiency
# ...
